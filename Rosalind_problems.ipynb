# %%
#problem 1 DNA
fn=open("../rosalind_dna(4).txt", "r")
olig=fn.read()
print(olig.count('A'), olig.count('C'), olig.count('G'),olig.count('T'))
# Out:
# 212 255 238 234

# %%
#problem 2 RNA
fn=open("../rosalind_rna.txt")
dna=fn.read()
rna=dna.replace('T','U')
print(rna)
# Out:
# ...

# %%
#problem 3 REVC

#dictionary
transcr={'A':'T', 'T':'A', 'C':'G', 'G':'C'}

with open("../rosalind_revc.txt") as fn:
    dna=fn.read()
    dnarev=dna.strip()[::-1]
    print(*(transcr[i] for i in dnarev), sep="")
# Out:
# ...

# %%
##Problem4 PROT

map = {"UUU":"F", "UUC":"F", "UUA":"L", "UUG":"L",
    "UCU":"S", "UCC":"S", "UCA":"S", "UCG":"S",
    "UAU":"Y", "UAC":"Y", "UAA":"STOP", "UAG":"STOP",
    "UGU":"C", "UGC":"C", "UGA":"STOP", "UGG":"W",
    "CUU":"L", "CUC":"L", "CUA":"L", "CUG":"L",
    "CCU":"P", "CCC":"P", "CCA":"P", "CCG":"P",
    "CAU":"H", "CAC":"H", "CAA":"Q", "CAG":"Q",
    "CGU":"R", "CGC":"R", "CGA":"R", "CGG":"R",
    "AUU":"I", "AUC":"I", "AUA":"I", "AUG":"M",
    "ACU":"T", "ACC":"T", "ACA":"T", "ACG":"T",
    "AAU":"N", "AAC":"N", "AAA":"K", "AAG":"K",
    "AGU":"S", "AGC":"S", "AGA":"R", "AGG":"R",
    "GUU":"V", "GUC":"V", "GUA":"V", "GUG":"V",
    "GCU":"A", "GCC":"A", "GCA":"A", "GCG":"A",
    "GAU":"D", "GAC":"D", "GAA":"E", "GAG":"E",
    "GGU":"G", "GGC":"G", "GGA":"G", "GGG":"G",}

fn = open("../rosalind_prot.txt")
rna=fn.read()
prot=[]
for i in range(0,len(rna),3):
    seq=rna[i:i+3]
    if(map[seq]) == "STOP":
        break
    prot.append(map[seq])

print(*(x for x in prot), sep='')
# Out:
# ...
